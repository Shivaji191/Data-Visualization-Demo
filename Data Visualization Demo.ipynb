# %% [markdown]
# ## seaborn

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
h=sns.load_dataset("healthexp")
h
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
sns.lineplot(x="Country",y="Life_Expectancy",data=h,size=15,)
plt.show()

# %%
sns.lineplot(x="Country",y="Spending_USD",data=h,)
plt.title("USD DATA")
plt.show()

# %%
sns.barplot(x="Country",y="Life_Expectancy",data=h)
plt.show()

# %%
sns.boxplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.scatterplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.violinplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.stripplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.swarmplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
sns.histplot(x="Country",y="Life_Expectancy",data=h)
# Out:
# <Axes: xlabel='Country', ylabel='Life_Expectancy'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s=sns.load_dataset("flights")
s
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
sns.lineplot(x="month",y="passengers",data=s,)
plt.title("Flight data")
plt.show()

# %%
sns.histplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
sns.scatterplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
sns.barplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
sns.boxplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
sns.violinplot(x="month",y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()

# %%
s
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
s.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
s.describe(include="all")
# Out:
#                year month  passengers
# count    144.000000   144  144.000000
# unique          NaN    12         NaN
# top             NaN   Jan         NaN
# freq            NaN    12         NaN
# mean    1954.500000   NaN  280.298611
# std        3.464102   NaN  119.966317
# min     1949.000000   NaN  104.000000
# 25%     1951.750000   NaN  180.000000
# 50%     1954.500000   NaN  265.500000
# 75%     1957.250000   NaN  360.500000
# max     1960.000000   NaN  622.000000

# %%
sns.countplot(x="month",data=s,color="b")
plt.title("Flight data")
plt.show()

# %%
sns.barplot(y="passengers",data=s,color="g")
plt.title("Flight data")
plt.show()
